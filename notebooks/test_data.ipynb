# %%
from torchvision import datasets, transforms

# %%
a = datasets.ImageNet(root='/scratch/narjis/imagenet/', download=True, split="val",transform=transforms.ToTensor())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 a = datasets.ImageNet(root='/scratch/narjis/imagenet/', download=True, split="val",transform=transforms.ToTensor())
#
# File ~/miniconda3/envs/kimeko/lib/python3.11/site-packages/torchvision/datasets/imagenet.py:56, in ImageNet.__init__(self, root, split, **kwargs)
#      53 root = self.root = os.path.expanduser(root)
#      54 self.split = verify_str_arg(split, "split", ("train", "val"))
# ---> 56 self.parse_archives()
#      57 wnid_to_classes = load_meta_file(self.root)[0]
#      59 super().__init__(self.split_folder, **kwargs)
#
# File ~/miniconda3/envs/kimeko/lib/python3.11/site-packages/torchvision/datasets/imagenet.py:69, in ImageNet.parse_archives(self)
#      67 def parse_archives(self) -> None:
#      68     if not check_integrity(os.path.join(self.root, META_FILE)):
# ...
